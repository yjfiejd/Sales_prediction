# %%
import numpy as np

# %%
def ToWeight(y):
    w = np.zeros(y.shape, dtype=float)
    print(w)
    ind = y != 0
    w[ind] = 1./(y[ind]**2)
    print(w[ind])
    return w

# %%
a = np.array([1, 2, 3, 4])
b = ToWeight(a)
b
# Out:
# [0. 0. 0. 0.]
# [1.         0.25       0.11111111 0.0625    ]
# array([1.        , 0.25      , 0.11111111, 0.0625    ])

# %%
def rmspe(yhat, y):
    w = ToWeight(y)
    rmspe = np.sqrt(np.mean(w * (y - yhat) ** 2))
    print(w*(y-yhat)**2)
    print(np.mean(w * (y - yhat) ** 2))
    print(rmspe)
    return  rmspe

# %%
yhat = np.array([1, 1, 1, 1])
c = rmspe(yhat, a)
c
# Out:
# [0. 0. 0. 0.]
# [1.         0.25       0.11111111 0.0625    ]
# [0.         0.25       0.44444444 0.5625    ]
# 0.3142361111111111
# 0.5605676686280713
# 0.5605676686280713

# %%
y = np.array([1, 2, 2, 3])

# %%
date = ['2015-12-1', '2015-1-30', '2017-9-18']
date
# Out:
# ['2015-12-1', '2015-1-30', '2017-9-18']

# %%
def month(x):
    for x in date:
        #x = x.split('-')[0]
        lambda x: x.split('-')[0]
    return x
month(date)
# Out:
# '2017-9-18'

# %%
import os
import pandas as pd

os.chdir('/Users/a1/Desktop/learning/kaggle_07/')

# %%
store = pd.read_csv('store.csv')
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
train_df = pd.read_csv('train.csv')
train_df.head()
# Out:
# /Users/a1/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
test_df = pd.read_csv('test.csv')
test_df.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %%
def load_data():
    '''
    加载数据，分为数值型与非数值型
    '''
    #导入store数据，
    store = pd.read_csv('store.csv')
    train_org = pd.read_csv('train.csv', dtype={'StateHoliday':pd.np.string_})
    test_org = pd.read_csv('test.csv', dtype={'StateHoliday':pd.np.string_})
    #合并数据作为train， test
    train = pd.merge(train_org, store, on='Store', how='left')
    test = pd.merge(test_org, store, on='Store', how = 'left')
    #定义数值型特征和非数值型特征
    features = test.columns.tolist() #把array格式转化为list格式
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    features_numeric = test.select_dtypes(include=numerics).columns.tolist()
    features_non_numeric = [f for f in features if f not in features_numeric]
    return (train, test, features, features_non_numeric)

# %%
store = pd.read_csv('store.csv')
train_org = pd.read_csv('train.csv', dtype={'StateHoliday':pd.np.string_})
test_org = pd.read_csv('test.csv', dtype={'StateHoliday':pd.np.string_})
   
train = pd.merge(train_org, store, on='Store', how='left')
train
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# 5            6          5  2015-07-31   5651        589     1      1
# 6            7          5  2015-07-31  15344       1414     1      1
# 7            8          5  2015-07-31   8492        833     1      1
# 8            9          5  2015-07-31   8565        687     1      1
# 9           10          5  2015-07-31   7185        681     1      1
# 10          11          5  2015-07-31  10457       1236     1      1
# 11          12          5  2015-07-31   8959        962     1      1
# 12          13          5  2015-07-31   8821        568     1      1
# ...

# %%
test = pd.merge(test_org, store, on='Store', how = 'left')
test
# Out:
#           Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 0          1      1          4  2015-09-17   1.0      1            0
# 1          2      3          4  2015-09-17   1.0      1            0
# 2          3      7          4  2015-09-17   1.0      1            0
# 3          4      8          4  2015-09-17   1.0      1            0
# 4          5      9          4  2015-09-17   1.0      1            0
# 5          6     10          4  2015-09-17   1.0      1            0
# 6          7     11          4  2015-09-17   1.0      1            0
# 7          8     12          4  2015-09-17   1.0      1            0
# 8          9     13          4  2015-09-17   1.0      1            0
# 9         10     14          4  2015-09-17   1.0      1            0
# 10        11     15          4  2015-09-17   1.0      1            0
# 11        12     16          4  2015-09-17   1.0      1            0
# 12        13     19          4  2015-09-17   1.0      1            0
# ...

# %%
# for year in [train,test]:
#     train['year'] = data.Date.apply(lambda x: x.split('-')[0])
#     data['year'] = data['year'].astype(float)
# return data['year']
a = [train, test]
print(len(train))
print(len(test))
print(len(a))
# Out:
# 1017209
# 41088
# 2

# %%
data1 = train.PromoInterval
data1
# Out:
# 0                       NaN
# 1           Jan,Apr,Jul,Oct
# 2           Jan,Apr,Jul,Oct
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10          Jan,Apr,Jul,Oct
# 11          Jan,Apr,Jul,Oct
# 12          Feb,May,Aug,Nov
# 13          Jan,Apr,Jul,Oct
# 14          Jan,Apr,Jul,Oct
# 15                      NaN
# 16          Jan,Apr,Jul,Oct
# 17          Jan,Apr,Jul,Oct
# 18         Mar,Jun,Sept,Dec
# 19          Jan,Apr,Jul,Oct
# 20          Jan,Apr,Jul,Oct
# 21          Jan,Apr,Jul,Oct
# 22                      NaN
# 23          Jan,Apr,Jul,Oct
# 24                      NaN
# 25                      NaN
# 26          Jan,Apr,Jul,Oct
# 27         Mar,Jun,Sept,Dec
# 28                      NaN
# 29         Mar,Jun,Sept,Dec
#                  ...
# 1017179     Feb,May,Aug,Nov
# 1017180                 NaN
# ...

# %%
data1.apply(lambda x: 0 if isinstance(x, float) else 1 if "Jan" in x else 0)
# Out:
# 0          0
# 1          1
# 2          1
# 3          0
# 4          0
# 5          0
# 6          0
# 7          0
# 8          0
# 9          0
# 10         1
# 11         1
# 12         0
# 13         1
# 14         1
# 15         0
# 16         1
# 17         1
# 18         0
# 19         1
# 20         1
# 21         1
# 22         0
# 23         1
# 24         0
# 25         0
# 26         1
# 27         0
# 28         0
# 29         0
#           ..
# 1017179    0
# 1017180    0
# 1017181    1
# 1017182    0
# 1017183    1
# 1017184    0
# 1017185    1
# 1017186    0
# 1017187    1
# 1017188    1
# 1017189    0
# 1017190    0
# 1017191    0
# 1017192    1
# 1017193    1
# 1017194    0
# 1017195    1
# 1017196    0
# 1017197    1
# 1017198    0
# 1017199    1
# 1017200    1
# 1017201    0
# 1017202    1
# 1017203    0
# 1017204    1
# 1017205    0
# 1017206    0
# 1017207    0
# 1017208    0
# Name: PromoInterval, Length: 1017209, dtype: int64

# %%
noisy_features = [myid,'Date']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-87d509afc653> in <module>()
# ----> 1 noisy_features = [myid,'Date']
#
# NameError: name 'myid' is not defined

# %%
params = 'hah'
print("Running with params: " + str(params))
# Out:
# Running with params: hah
